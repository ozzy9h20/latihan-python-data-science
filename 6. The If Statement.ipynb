# %%
import numpy as np
from numpy.random import randn

# %%
randn()
# Out:
# -1.079656390957183

# %%
answer = None
x = randn()
if x > 1:
    answer = "Greater than 1"

print(x)
print(answer)
# Out:
# 1.0522877784038513
# Greater than 1

# %%
answer = None
x = randn()
if x > 1:
    answer = "Greater than 1"
else: 
    answer = "Less than 1"
print(x)
print(answer)
# Out:
# 1.5532352302941472
# Greater than 1

# %%
answer = None
x = randn()
if x > 1:
    answer = "Greater than 1"
elif x>= -1:
    answer = "Between -1 and 1"
else: 
    answer = "Less than 1"
print(x)
print(answer)
# Out:
# -0.20076136009735956
# Between -1 and 1
